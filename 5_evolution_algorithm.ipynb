# %% [markdown]
# # Evolution Algorithm
# SALMAN SHAH | SPRINGBOARD
# ## Objective
# The purpose of this notebook is to automate the hyperparameter searching process for my super-resolution model. The goal would be to leave a setup running in a continous loop that randomly generates hyperparameter values (within reason), trains the model, and saves the results. After a few days of iterations, I can compare the results and choose the best model.
#
# The setup is designed to run in google colab using their provided GPU. In the case of an exhaustion error, the hyperparameters are scrapped and the iteration is rerun with new hyperparameters.

# %% [markdown]
# ## Helper functions
# The functions below are helper functions used to execute the continous loop at the bottom. The elements involved are:
# - a set of hyperparamters `h`
# - a function `randomize_hyperparameters` to choose random hyperparameters
# - a function `residual_block` which returns the residual block component of the model architecture
# - a function `conv_block` which returns the convolutional blocks at the end of the model architecture
# - a function `upsample` which returns the 2x upsample block
# - a function `build_model` which returns the model using the components above
# - a function `build_dataset` which loads the dataset into memory
# - a function `get_filenames` used for fetching image filenames
# - two functions `display_results` and `display_error_plots` for printing plots onto the screen
# - two functions `save_results` and `save_error_plots` for saving the plots into local drive

# %%
from google.colab import files

import keras
from keras.layers import Conv2D, UpSampling2D, Input, Add
from keras.models import Model
from keras.regularizers import l1_l2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image
from numpy.random import randint
import numpy as np
import os

# hyperparameter
h = {
	"l1_parameter" : 0.01,		# for l1 regularizer. [0, 0.02]
	"l2_parameter" : 0.01,		# for l2 regularizer. [0, 0.02]
	"num_residual_blocks" : 4,	# number of residual blocks to use. [2,10]
	"num_conv_blocks" : 2, 		# number of conv blocks to use inside a residual block. [2,4]
	"num_final_conv_blocks" : 2,
	"num_epochs" : 100,			# train everything at 100 epochs for now
	"batch_size" : 16,			# lower this number if ResourceExhaustion errors occur
	"num_filters" : 64,			# [16,32,64,128]
	"learning_rate" : 0.0001,	# parameter for adam optimizer. [0.0001, 0.001]
	"beta_1" : 0.9,				# parameter for adam optimizer. ignore for now
	"beta_2" : 0.999			# parameter for adam optimizer. ignore for now
}
h.update({
	"optimizer" : keras.optimizers.Adam(lr=h['learning_rate'], beta_1=h['beta_1'], beta_2=h['beta_2'], amsgrad=False),
	'regularizer' : l1_l2(l1=h['l1_parameter'], l2=h['l2_parameter'])
})

# randomizes global variable h
def randomize_hyperparamters():
	global h
	# Note: N evenly spaced random points in interval [a,b) is given by:
	# a + (b - a) * randint(N)/N
	h.update({'l1_parameter' : 0.02 * randint(10) / 10,
			  'l2_parameter' : 0.02 * randint(10) / 10,
			  'num_residual_blocks' : np.random.choice([8,9,10,11,12,13,14,15]),
			  'num_conv_blocks' : np.random.choice([2,3,4]),
			  'num_final_conv_blocks' : np.random.choice([2,3,4]),
			  'num_filters' : np.random.choice([16,32,64,128]),
			  'learning_rate' : 0.00005 + (0.001 - 0.00005) * randint(20) / 20
		})
	h.update({"optimizer" : keras.optimizers.Adam(lr=h['learning_rate'], beta_1=h['beta_1'], beta_2=h['beta_2'], amsgrad=False),
			  'regularizer' : l1_l2(l1=h['l1_parameter'], l2=h['l2_parameter'])})

# a residual block
def residual_block(input_layer, activation='relu', kernel_size=(3,3)):
	global h
	layer = input_layer
	for i in range(h['num_conv_blocks']):
		layer = Conv2D(h['num_filters'], kernel_size, padding='same', activation=activation, activity_regularizer=h['regularizer'])(layer)
	conv_1x1 = Conv2D(3, (1,1), padding='same')(layer)
	return Add()([conv_1x1, input_layer])

# final convolution blocks
def conv_block(input_layer, kernel_size=(3,3)):
	global h
	layer = input_layer
	for i in range(h['num_final_conv_blocks']):
		layer = Conv2D(h['num_filters'], kernel_size, padding='same', activation='relu')(layer)
	return layer

# upsamples 2x
def upsample(layer):
	return UpSampling2D(size=(2,2))(layer)

# builds model based on hyperparameter specs
def build_model():
  global h
  input_layer = Input(shape=(150,150,3))
  layer = input_layer
  # layer = residual_block(input_layer, h['num_filters'])
  for i in range(h['num_residual_blocks']):
    layer = residual_block(layer)
  layer = upsample(layer)
  layer = conv_block(layer)
  output_layer = Conv2D(3, (1,1), padding='same')(layer)
  return Model(inputs=input_layer, outputs=output_layer)

# returns dataset in (x_train, y_train), (x_test, y_test) format
def build_dataset(directory):
	# initialize variables
	filenames = get_filenames(directory)
	X = []
	Y = []

	# collect images from directory
	for filename in filenames:
		print("Processing", filename)
		image = Image.open(directory + filename)
		image_large = np.array(image)
		image_small = np.array(image.resize((150,150)))
		Y.append(image_large)
		X.append(image_small)

	# convert to matrices
	X = np.asarray(X)
	X = X.astype('float32')
	X /= 255
	Y = np.asarray(Y)
	Y = Y.astype('float32')
	Y /= 255

	x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

	# following keras convention for load_data() 
	return ((x_train, y_train), (x_test, y_test))

# helper function for getting image file names
def get_filenames(directory):
	for _,_,filenames in os.walk(directory):
		pass
	return filenames

# show results of a trained model 
def display_results(model, n=10, img_size=10):
	if n > 1:
		fig, axs = plt.subplots(n, 3, figsize=(3 * img_size, n * img_size))
		for index, ax in enumerate(axs):
			ax[0].imshow(x_test[index])
			ax[0].axis('off')
			ax[1].imshow(y_test[index])
			ax[1].axis('off')
			y_pred = model.predict(x_test[index:index+1])[0]
			ax[2].imshow(y_pred)
			ax[2].axis('off')
		plt.show()
	else:
		print("n must be at least 2")

# plot accuracy and error over epochs
def display_error_plots(hist):
	if type(hist) == keras.callbacks.History:
		acc = hist.history['acc']
		val_acc = hist.history['val_acc']
		loss = hist.history['loss']
		val_loss = hist.history['val_loss']

		fig, axs = plt.subplots(1,2, figsize=(15,5))
		axs[0].plot(acc, label='Training accuracy')
		axs[0].plot(val_acc, label='Validation accuracy')
		axs[0].legend(loc='lower right')
		axs[0].set_title("Accuracy")
		axs[1].plot(loss, label='Training error')
		axs[1].plot(val_loss, label='Validation error')
		axs[1].legend()
		axs[1].set_title("Error")
		plt.show()
	else:
		raise TypeError("Expected object of type keras.callbacks.History not " + type(hist).__name__)
  
# save error and accuracy plots
def save_error_plots(hist):
	acc = hist.history['acc']
	val_acc = hist.history['val_acc']
	loss = hist.history['loss']
	val_loss = hist.history['val_loss']

	fig, axs = plt.subplots(1,2, figsize=(15,5))
	axs[0].plot(acc, label='Training accuracy')
	axs[0].plot(val_acc, label='Validation accuracy')
	axs[0].legend(loc='lower right')
	axs[0].set_title("Accuracy")
	axs[1].plot(loss, label='Training error')
	axs[1].plot(val_loss, label='Validation error')
	axs[1].legend()
	axs[1].set_title("Error")

	plt.savefig('plots.png')

# save final images comparing results
def save_results(model):
  fig, axs = plt.subplots(10, 3, figsize=(30,100))
  for index, ax in enumerate(axs):
    ax[0].imshow(x_test[index])
    ax[0].axis('off')
    ax[1].imshow(y_test[index])
    ax[1].axis('off')
    y_pred = model.predict(x_test[index:index+1])[0]
    ax[2].imshow(y_pred)
    ax[2].axis('off')
  plt.savefig('results.png')
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Continous Loop
# The setup below runs indefintely in a loop until manually stopped.
#
# In each iteration, a model is trained with randomly chosen hyperparameters. At the end of the iteration, the model architecture, hyperparameters, weights, and plots are saved and stored in a zip file.

# %%
# load google drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# get dataset
directory = 'gdrive/My Drive/Projects/Data Science/Super Resolution/dataset/downscaled/'
(x_train, y_train), (x_test, y_test) = build_dataset(directory)
# Out:
# Processing 1078.png
# Processing 1076.png
# Processing 1079.png
# Processing 108.png
# Processing 109.png
# Processing 1081.png
# Processing 1084.png
# Processing 1083.png
# Processing 1082.png
# Processing 1086.png
# Processing 1085.png
# Processing 1080.png
# Processing 11.png
# Processing 1087.png
# Processing 110.png
# Processing 111.png
# Processing 112.png
# Processing 113.png
# Processing 115.png
# Processing 114.png
# Processing 12.png
# Processing 117.png
# Processing 116.png
# Processing 118.png
# Processing 119.png
# Processing 120.png
# Processing 121.png
# Processing 122.png
# Processing 123.png
# Processing 126.png
# Processing 124.png
# Processing 125.png
# Processing 130.png
# Processing 131.png
# Processing 128.png
# Processing 127.png
# Processing 129.png
# Processing 13.png
# Processing 132.png
# Processing 133.png
# Processing 134.png
# Processing 137.png
# Processing 136.png
# Processing 135.png
# Processing 142.png
# Processing 141.png
# Processing 140.png
# Processing 138.png
# Processing 14.png
# Processing 139.png
# Processing 143.png
# Processing 144.png
# Processing 152.png
# Processing 146.png
# Processing 145.png
# Processing 147.png
# Processing 153.png
# Processing 150.png
# Processing 151.png
# Processing 15.png
# Processing 148.png
# Processing 149.png
# Processing 154.png
# Processing 155.png
# Processing 156.png
# Processing 158.png
# Processing 159.png
# Processing 157.png
# Processing 16.png
# Processing 163.png
# Processing 164.png
# Processing 161.png
# Processing 160.png
# Processing 162.png
# Processing 165.png
# Processing 166.png
# Processing 169.png
# Processing 17.png
# Processing 168.png
# Processing 167.png
# Processing 174.png
# Processing 175.png
# Processing 171.png
# Processing 170.png
# Processing 176.png
# Processing 172.png
# Processing 177.png
# Processing 173.png
# Processing 178.png
# Processing 186.png
# Processing 181.png
# Processing 180.png
# Processing 182.png
# Processing 18.png
# Processing 179.png
# Processing 187.png
# Processing 185.png
# Processing 183.png
# Processing 184.png
# Processing 188.png
# Processing 189.png
# Processing 197.png
# Processing 19.png
# Processing 192.png
# Processing 191.png
# Processing 190.png
# Processing 198.png
# Processing 195.png
# Processing 194.png
# Processing 193.png
# Processing 196.png
# Processing 199.png
# Processing 20.png
# Processing 207.png
# Processing 203.png
# Processing 202.png
# Processing 205.png
# Processing 200.png
# Processing 201.png
# Processing 204.png
# Processing 208.png
# Processing 2.png
# Processing 206.png
# Processing 209.png
# Processing 21.png
# Processing 218.png
# Processing 212.png
# Processing 211.png
# Processing 215.png
# Processing 213.png
# Processing 210.png
# Processing 219.png
# Processing 216.png
# Processing 217.png
# Processing 214.png
# Processing 22.png
# Processing 220.png
# Processing 229.png
# Processing 222.png
# Processing 224.png
# Processing 223.png
# Processing 221.png
# Processing 23.png
# Processing 226.png
# Processing 225.png
# Processing 228.png
# Processing 227.png
# Processing 230.png
# Processing 231.png
# Processing 24.png
# Processing 232.png
# Processing 234.png
# Processing 233.png
# Processing 235.png
# Processing 240.png
# Processing 238.png
# Processing 236.png
# Processing 239.png
# Processing 237.png
# Processing 241.png
# Processing 242.png
# Processing 250.png
# Processing 245.png
# Processing 246.png
# Processing 244.png
# Processing 243.png
# Processing 247.png
# Processing 249.png
# Processing 25.png
# Processing 248.png
# Processing 252.png
# Processing 253.png
# Processing 254.png
# Processing 255.png
# Processing 256.png
# Processing 258.png
# Processing 257.png
# Processing 259.png
# Processing 26.png
# Processing 251.png
# Processing 260.png
# Processing 269.png
# Processing 262.png
# Processing 263.png
# Processing 261.png
# Processing 27.png
# Processing 267.png
# Processing 264.png
# Processing 266.png
# Processing 268.png
# Processing 265.png
# Processing 270.png
# Processing 271.png
# Processing 273.png
# Processing 275.png
# Processing 274.png
# Processing 272.png
# Processing 28.png
# Processing 280.png
# Processing 278.png
# Processing 276.png
# Processing 277.png
# Processing 279.png
# Processing 281.png
# Processing 282.png
# Processing 290.png
# Processing 285.png
# Processing 284.png
# Processing 286.png
# Processing 283.png
# Processing 291.png
# Processing 29.png
# Processing 288.png
# Processing 289.png
# Processing 287.png
# Processing 292.png
# Processing 293.png
# Processing 300.png
# Processing 299.png
# Processing 294.png
# Processing 296.png
# Processing 295.png
# Processing 297.png
# Processing 298.png
# Processing 301.png
# Processing 30.png
# Processing 3.png
# Processing 302.png
# Processing 303.png
# Processing 311.png
# Processing 305.png
# Processing 307.png
# Processing 306.png
# Processing 304.png
# Processing 308.png
# Processing 312.png
# Processing 31.png
# Processing 309.png
# Processing 310.png
# Processing 313.png
# Processing 314.png
# Processing 315.png
# Processing 317.png
# Processing 319.png
# Processing 316.png
# Processing 318.png
# Processing 322.png
# Processing 323.png
# Processing 320.png
# Processing 321.png
# Processing 32.png
# Processing 326.png
# Processing 328.png
# Processing 325.png
# Processing 324.png
# Processing 327.png
# Processing 332.png
# Processing 333.png
# Processing 331.png
# Processing 33.png
# Processing 329.png
# Processing 330.png
# Processing 334.png
# Processing 335.png
# Processing 34.png
# Processing 338.png
# Processing 336.png
# Processing 339.png
# Processing 337.png
# Processing 343.png
# Processing 344.png
# Processing 342.png
# Processing 341.png
# Processing 340.png
# Processing 345.png
# Processing 346.png
# Processing 354.png
# Processing 355.png
# Processing 356.png
# Processing 357.png
# Processing 358.png
# Processing 35.png
# Processing 350.png
# Processing 347.png
# Processing 348.png
# Processing 352.png
# Processing 353.png
# Processing 349.png
# Processing 351.png
# Processing 359.png
# Processing 36.png
# Processing 368.png
# Processing 363.png
# Processing 360.png
# Processing 362.png
# Processing 361.png
# Processing 369.png
# Processing 367.png
# Processing 364.png
# Processing 365.png
# Processing 366.png
# Processing 37.png
# Processing 370.png
# Processing 372.png
# Processing 373.png
# Processing 374.png
# Processing 371.png
# Processing 379.png
# Processing 38.png
# Processing 375.png
# Processing 378.png
# Processing 377.png
# Processing 376.png
# Processing 380.png
# Processing 381.png
# Processing 39.png
# Processing 384.png
# Processing 383.png
# Processing 382.png
# Processing 390.png
# Processing 386.png
# Processing 385.png
# Processing 387.png
# Processing 389.png
# Processing 388.png
# Processing 391.png
# Processing 394.png
# Processing 393.png
# Processing 392.png
# Processing 4.png
# Processing 40.png
# Processing 398.png
# Processing 396.png
# Processing 399.png
# Processing 397.png
# Processing 395.png
# Processing 400.png
# Processing 401.png
# Processing 402.png
# Processing 403.png
# Processing 404.png
# Processing 405.png
# Processing 41.png
# Processing 410.png
# Processing 406.png
# Processing 408.png
# Processing 407.png
# Processing 409.png
# Processing 411.png
# Processing 412.png
# Processing 420.png
# Processing 416.png
# Processing 415.png
# Processing 417.png
# Processing 413.png
# Processing 414.png
# Processing 421.png
# Processing 418.png
# Processing 42.png
# Processing 419.png
# Processing 422.png
# Processing 423.png
# Processing 431.png
# Processing 429.png
# Processing 426.png
# Processing 425.png
# Processing 427.png
# Processing 430.png
# Processing 428.png
# Processing 43.png
# Processing 424.png
# Processing 432.png
# Processing 433.png
# Processing 441.png
# Processing 438.png
# Processing 434.png
# Processing 437.png
# Processing 435.png
# Processing 436.png
# Processing 442.png
# Processing 443.png
# Processing 44.png
# Processing 440.png
# Processing 439.png
# Processing 444.png
# Processing 445.png
# Processing 446.png
# Processing 454.png
# Processing 448.png
# Processing 449.png
# Processing 447.png
# Processing 45.png
# Processing 450.png
# Processing 451.png
# Processing 455.png
# Processing 453.png
# Processing 452.png
# Processing 456.png
# Processing 457.png
# Processing 458.png
# Processing 460.png
# Processing 459.png
# Processing 46.png
# Processing 465.png
# Processing 466.png
# Processing 461.png
# Processing 462.png
# Processing 464.png
# Processing 463.png
# Processing 467.png
# Processing 468.png
# Processing 476.png
# Processing 469.png
# Processing 47.png
# Processing 471.png
# Processing 470.png
# Processing 472.png
# Processing 474.png
# Processing 473.png
# Processing 475.png
# Processing 477.png
# Processing 478.png
# Processing 479.png
# Processing 483.png
# Processing 48.png
# Processing 481.png
# Processing 480.png
# Processing 482.png
# Processing 487.png
# Processing 488.png
# Processing 485.png
# Processing 486.png
# Processing 484.png
# Processing 489.png
# Processing 49.png
# Processing 498.png
# Processing 490.png
# Processing 492.png
# Processing 491.png
# Processing 493.png
# Processing 499.png
# Processing 497.png
# Processing 496.png
# Processing 495.png
# Processing 494.png
# Processing 5.png
# Processing 500.png
# Processing 508.png
# Processing 502.png
# Processing 501.png
# Processing 503.png
# Processing 50.png
# Processing 509.png
# Processing 504.png
# Processing 505.png
# Processing 506.png
# Processing 507.png
# Processing 51.png
# Processing 510.png
# Processing 511.png
# Processing 515.png
# Processing 514.png
# Processing 512.png
# Processing 513.png
# Processing 52.png
# Processing 519.png
# Processing 518.png
# Processing 516.png
# Processing 517.png
# Processing 520.png
# Processing 521.png
# Processing 522.png
# Processing 526.png
# Processing 528.png
# Processing 529.png
# Processing 525.png
# Processing 527.png
# Processing 524.png
# Processing 523.png
# Processing 530.png
# Processing 53.png
# Processing 531.png
# Processing 532.png
# Processing 533.png
# Processing 534.png
# Processing 538.png
# Processing 536.png
# Processing 535.png
# Processing 537.png
# Processing 541.png
# Processing 542.png
# Processing 539.png
# Processing 540.png
# Processing 54.png
# Processing 543.png
# Processing 544.png
# Processing 547.png
# Processing 548.png
# Processing 545.png
# Processing 546.png
# Processing 552.png
# Processing 551.png
# Processing 549.png
# Processing 55.png
# Processing 550.png
# Processing 553.png
# Processing 554.png
# Processing 555.png
# Processing 556.png
# Processing 559.png
# Processing 558.png
# Processing 557.png
# Processing 56.png
# Processing 560.png
# Processing 564.png
# Processing 565.png
# Processing 561.png
# Processing 562.png
# Processing 563.png
# Processing 566.png
# Processing 567.png
# Processing 575.png
# Processing 568.png
# Processing 569.png
# Processing 573.png
# Processing 570.png
# Processing 571.png
# Processing 572.png
# Processing 57.png
# Processing 574.png
# Processing 576.png
# Processing 577.png
# Processing 578.png
# Processing 586.png
# Processing 580.png
# Processing 582.png
# Processing 58.png
# Processing 579.png
# Processing 581.png
# Processing 585.png
# Processing 584.png
# Processing 583.png
# Processing 587.png
# Processing 588.png
# Processing 589.png
# Processing 59.png
# Processing 592.png
# Processing 593.png
# Processing 591.png
# Processing 590.png
# Processing 597.png
# Processing 598.png
# Processing 594.png
# Processing 595.png
# Processing 596.png
# Processing 599.png
# Processing 6.png
# Processing 607.png
# Processing 601.png
# Processing 603.png
# Processing 600.png
# Processing 604.png
# Processing 602.png
# Processing 60.png
# Processing 608.png
# Processing 606.png
# Processing 605.png
# Processing 609.png
# Processing 61.png
# Processing 611.png
# Processing 613.png
# Processing 612.png
# Processing 610.png
# Processing 618.png
# Processing 619.png
# Processing 616.png
# Processing 615.png
# Processing 617.png
# Processing 614.png
# Processing 62.png
# Processing 621.png
# Processing 629.png
# Processing 620.png
# Processing 622.png
# Processing 63.png
# Processing 627.png
# Processing 624.png
# Processing 628.png
# Processing 626.png
# Processing 623.png
# Processing 625.png
# Processing 630.png
# Processing 631.png
# Processing 634.png
# Processing 638.png
# Processing 635.png
# Processing 636.png
# Processing 632.png
# Processing 637.png
# Processing 633.png
# Processing 64.png
# Processing 640.png
# Processing 641.png
# Processing 642.png
# Processing 639.png
# Processing 643.png
# Processing 651.png
# Processing 645.png
# Processing 644.png
# Processing 646.png
# Processing 647.png
# Processing 649.png
# Processing 65.png
# Processing 650.png
# Processing 648.png
# Processing 652.png
# Processing 653.png
# Processing 654.png
# Processing 662.png
# Processing 656.png
# Processing 655.png
# Processing 657.png
# Processing 663.png
# Processing 66.png
# Processing 659.png
# Processing 660.png
# Processing 658.png
# Processing 661.png
# Processing 664.png
# Processing 665.png
# Processing 673.png
# Processing 667.png
# Processing 668.png
# Processing 666.png
# Processing 674.png
# Processing 670.png
# Processing 67.png
# Processing 669.png
# Processing 671.png
# Processing 672.png
# Processing 675.png
# Processing 676.png
# Processing 684.png
# Processing 68.png
# Processing 680.png
# Processing 679.png
# Processing 678.png
# Processing 681.png
# Processing 677.png
# Processing 683.png
# Processing 682.png
# Processing 686.png
# Processing 685.png
# Processing 687.png
# Processing 690.png
# Processing 689.png
# Processing 688.png
# Processing 69.png
# Processing 691.png
# Processing 694.png
# Processing 695.png
# Processing 693.png
# Processing 692.png
# Processing 696.png
# Processing 697.png
# Processing 700.png
# Processing 70.png
# Processing 698.png
# Processing 699.png
# Processing 7.png
# Processing 704.png
# Processing 705.png
# Processing 703.png
# Processing 702.png
# Processing 701.png
# Processing 706.png
# Processing 707.png
# Processing 709.png
# Processing 710.png
# Processing 71.png
# Processing 708.png
# Processing 715.png
# Processing 716.png
# Processing 714.png
# Processing 713.png
# Processing 711.png
# Processing 712.png
# Processing 717.png
# Processing 718.png
# Processing 719.png
# Processing 721.png
# Processing 72.png
# Processing 720.png
# Processing 726.png
# Processing 727.png
# Processing 724.png
# Processing 723.png
# Processing 722.png
# Processing 725.png
# Processing 728.png
# Processing 729.png
# Processing 731.png
# Processing 730.png
# Processing 732.png
# Processing 733.png
# Processing 73.png
# Processing 737.png
# Processing 738.png
# Processing 734.png
# Processing 736.png
# Processing 735.png
# Processing 739.png
# Processing 74.png
# Processing 743.png
# Processing 741.png
# Processing 740.png
# Processing 742.png
# Processing 748.png
# Processing 749.png
# Processing 746.png
# Processing 744.png
# Processing 747.png
# Processing 745.png
# Processing 75.png
# Processing 750.png
# Processing 751.png
# Processing 754.png
# Processing 755.png
# Processing 753.png
# Processing 752.png
# Processing 759.png
# Processing 76.png
# Processing 757.png
# Processing 758.png
# Processing 756.png
# Processing 760.png
# Processing 761.png
# Processing 762.png
# Processing 770.png
# Processing 764.png
# Processing 766.png
# Processing 765.png
# Processing 767.png
# Processing 763.png
# Processing 771.png
# Processing 772.png
# Processing 769.png
# Processing 77.png
# Processing 768.png
# Processing 773.png
# Processing 775.png
# Processing 782.png
# Processing 774.png
# Processing 776.png
# Processing 779.png
# Processing 778.png
# Processing 777.png
# Processing 783.png
# Processing 781.png
# Processing 78.png
# Processing 780.png
# Processing 784.png
# Processing 785.png
# Processing 786.png
# Processing 788.png
# Processing 787.png
# Processing 793.png
# Processing 794.png
# Processing 79.png
# Processing 792.png
# Processing 789.png
# Processing 791.png
# Processing 790.png
# Processing 795.png
# Processing 796.png
# Processing 803.png
# Processing 797.png
# Processing 8.png
# Processing 798.png
# Processing 799.png
# Processing 804.png
# Processing 801.png
# Processing 800.png
# Processing 80.png
# Processing 802.png
# Processing 805.png
# Processing 806.png
# Processing 81.png
# Processing 807.png
# Processing 809.png
# Processing 808.png
# Processing 814.png
# Processing 815.png
# Processing 812.png
# Processing 811.png
# Processing 813.png
# Processing 810.png
# Processing 816.png
# Processing 817.png
# Processing 819.png
# Processing 82.png
# Processing 818.png
# Processing 825.png
# Processing 826.png
# Processing 820.png
# Processing 822.png
# Processing 821.png
# Processing 823.png
# Processing 824.png
# Processing 827.png
# Processing 828.png
# Processing 832.png
# Processing 83.png
# Processing 829.png
# Processing 830.png
# Processing 831.png
# Processing 836.png
# Processing 837.png
# Processing 834.png
# Processing 833.png
# Processing 835.png
# Processing 838.png
# Processing 839.png
# Processing 843.png
# Processing 844.png
# Processing 842.png
# Processing 841.png
# Processing 840.png
# Processing 84.png
# Processing 847.png
# Processing 848.png
# Processing 849.png
# Processing 845.png
# Processing 846.png
# Processing 85.png
# Processing 850.png
# Processing 859.png
# Processing 851.png
# Processing 853.png
# Processing 852.png
# Processing 86.png
# Processing 858.png
# Processing 854.png
# Processing 857.png
# Processing 856.png
# Processing 855.png
# Processing 861.png
# Processing 860.png
# Processing 865.png
# Processing 862.png
# Processing 864.png
# Processing 866.png
# Processing 863.png
# Processing 87.png
# Processing 867.png
# Processing 869.png
# Processing 868.png
# Processing 870.png
# Processing 871.png
# Processing 88.png
# Processing 876.png
# Processing 874.png
# Processing 875.png
# Processing 872.png
# Processing 877.png
# Processing 873.png
# Processing 880.png
# Processing 878.png
# Processing 879.png
# Processing 881.png
# Processing 882.png
# Processing 890.png
# Processing 884.png
# Processing 886.png
# Processing 885.png
# Processing 887.png
# Processing 883.png
# Processing 891.png
# Processing 889.png
# Processing 89.png
# Processing 888.png
# Processing 892.png
# Processing 893.png
# Processing 900.png
# Processing 896.png
# Processing 899.png
# Processing 897.png
# Processing 894.png
# Processing 898.png
# Processing 901.png
# Processing 9.png
# Processing 895.png
# Processing 90.png
# Processing 902.png
# Processing 903.png
# Processing 904.png
# Processing 907.png
# Processing 905.png
# Processing 906.png
# Processing 911.png
# Processing 912.png
# Processing 910.png
# Processing 908.png
# Processing 909.png
# Processing 91.png
# Processing 913.png
# Processing 914.png
# Processing 922.png
# Processing 915.png
# Processing 916.png
# Processing 918.png
# Processing 917.png
# Processing 923.png
# Processing 92.png
# Processing 921.png
# Processing 920.png
# Processing 924.png
# Processing 919.png
# Processing 925.png
# Processing 926.png
# Processing 934.png
# Processing 928.png
# Processing 929.png
# Processing 927.png
# Processing 93.png
# Processing 935.png
# Processing 932.png
# Processing 930.png
# Processing 931.png
# Processing 933.png
# Processing 936.png
# Processing 937.png
# Processing 945.png
# Processing 940.png
# Processing 938.png
# Processing 94.png
# Processing 939.png
# Processing 946.png
# Processing 943.png
# Processing 942.png
# Processing 941.png
# Processing 944.png
# Processing 947.png
# Processing 948.png
# Processing 956.png
# Processing 950.png
# Processing 95.png
# Processing 949.png
# Processing 957.png
# Processing 952.png
# Processing 953.png
# Processing 955.png
# Processing 954.png
# Processing 951.png
# Processing 958.png
# Processing 959.png
# Processing 967.png
# Processing 96.png
# Processing 960.png
# Processing 963.png
# Processing 962.png
# Processing 961.png
# Processing 968.png
# Processing 966.png
# Processing 965.png
# Processing 964.png
# Processing 969.png
# Processing 97.png
# Processing 970.png
# Processing 973.png
# Processing 971.png
# Processing 972.png
# Processing 978.png
# Processing 979.png
# Processing 977.png
# Processing 974.png
# Processing 975.png
# Processing 976.png
# Processing 98.png
# Processing 980.png
# Processing 989.png
# Processing 982.png
# Processing 984.png
# Processing 981.png
# Processing 983.png
# Processing 985.png
# Processing 99.png
# Processing 987.png
# Processing 986.png
# Processing 988.png
# Processing 990.png
# Processing 991.png
# Processing 996.png
# Processing 995.png
# Processing 993.png
# Processing 992.png
# Processing 994.png
# Processing 999.png
# Processing 998.png
# Processing 997.png
# Processing 100.png
# Processing 1000.png
# Processing 1001.png
# Processing 1.png
# Processing 10.png
# Processing 1002.png
# Processing 1003.png
# Processing 1005.png
# Processing 1004.png
# Processing 1007.png
# Processing 1006.png
# Processing 1011.png
# Processing 1012.png
# Processing 1010.png
# Processing 1009.png
# Processing 101.png
# Processing 1008.png
# Processing 1013.png
# Processing 1014.png
# Processing 1015.png
# Processing 1016.png
# Processing 1017.png
# Processing 1022.png
# Processing 1023.png
# Processing 1019.png
# Processing 1021.png
# Processing 102.png
# Processing 1020.png
# Processing 1018.png
# Processing 1024.png
# Processing 1025.png
# Processing 1033.png
# Processing 1027.png
# Processing 1029.png
# Processing 1028.png
# Processing 1026.png
# Processing 1034.png
# Processing 103.png
# Processing 1031.png
# Processing 1032.png
# Processing 1030.png
# Processing 1035.png
# Processing 1036.png
# Processing 1044.png
# Processing 104.png
# Processing 1040.png
# Processing 1038.png
# Processing 1039.png
# Processing 1037.png
# Processing 1045.png
# Processing 1041.png
# Processing 1042.png
# Processing 1043.png
# Processing 1046.png
# Processing 1047.png
# Processing 1055.png
# Processing 1051.png
# Processing 105.png
# Processing 1048.png
# Processing 1050.png
# Processing 1049.png
# Processing 1056.png
# Processing 1052.png
# Processing 1054.png
# Processing 1053.png
# Processing 1057.png
# Processing 1058.png
# Processing 1066.png
# Processing 1067.png
# Processing 1061.png
# Processing 1064.png
# Processing 1063.png
# Processing 1059.png
# Processing 106.png
# Processing 1065.png
# Processing 1060.png
# Processing 1062.png
# Processing 1068.png
# Processing 1069.png
# Processing 1077.png
# Processing 1073.png
# Processing 1072.png
# Processing 1074.png
# Processing 1070.png
# Processing 107.png
# Processing 1071.png
# Processing 1075.png

# %%
import time
import contextlib
import json

# ignore ugly tensorflow deprecation warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# h.update({'num_epochs' : 2}) # for testing only

evolution_iteration = 0
failed_attempts = 0
while(True):
  evolution_iteration += 1
  print("Iteration:", evolution_iteration)
  print("Total failed attempts:", failed_attempts)
  print("---------------------------------")
  print("Randomizing hyperparameters...")

  try:
    # pick random parameters
    randomize_hyperparamters()
    print('residual blocks:', h['num_residual_blocks'])
    print('conv blocks:', h['num_conv_blocks'])
    print('final conv blocks:', h['num_final_conv_blocks'])
    print('num_filters:', h['num_filters'])
    print('learning rate:', h['learning_rate'])
    print('l1:', h['l1_parameter'])
    print('l2:', h['l2_parameter'])
    print("---------------------------------")

    # build, compile and train model
    # NOTE: changed loss function from mse to mae on Dec 7, 2019
    model = build_model()
    model.compile(loss='mae', optimizer=h['optimizer'], metrics=['accuracy'])
    hist = model.fit(x_train, y_train, batch_size=h['batch_size'], epochs=h['num_epochs'], verbose=1, validation_data=(x_test, y_test))

    # record accuracy
    accuracy = model.evaluate(x_test, y_test)[1]

    # save stats by redirecting stdout to a file
    print("\nSaving files...")
    import sys
    orig_stdout = sys.stdout
    f = open('model_summary.txt', 'w')
    sys.stdout = f
    model.summary()   # save model 
    print("\nhyperparameters:", h, "\n") # save hyperparameters
    print("final validation accuracy:", accuracy) # save accuracy
    sys.stdout = orig_stdout
    f.close()

    print("Saving plots...")
    with contextlib.redirect_stdout(None): # bypass ugly matplotlib clipping errors
      save_error_plots(hist) # save accuracy and error plots
      save_results(model) # save image results

    # save model architecture
    print("Saving model architecture...")
    model_json = model.to_json()
    with open('model.json', 'w') as f:
      json.dump(model_json, f)

    # zip up files
    print("Zipping files...")
    # !zip {str(evolution_iteration)}.zip model_summary.txt results.png plots.png results.png model.json

    # store the zipped file
    print("Storing files in designated folder...")
    time.sleep(5)   # wait 5 seconds to ensure zipping is complete
    # !mv {str(evolution_iteration)}.zip gdrive/'My Drive'/Projects/'Data Science'/'Super Resolution'/final_models/

    print("Iteration", evolution_iteration, "successful.\n")
  except:
    # try again with new parameters if running into resource issuses
    print("Attempt Failed\n")
    failed_attempts += 1
# Out:
# Iteration: 1
# Total failed attempts: 0
# ---------------------------------
# Randomizing hyperparameters...
# residual blocks: 14
# conv blocks: 4
# final conv blocks: 4
# num_filters: 32
# learning rate: 0.0008100000000000001
# l1: 0.018
# l2: 0.018
# ---------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 869 samples, validate on 218 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 869/869 [==============================] - 43s 49ms/step - loss: 86848.6870 - acc: 0.4071 - val_loss: 28412.5004 - val_acc: 0.2576
# Epoch 2/100
# 869/869 [==============================] - 29s 33ms/step - loss: 21548.3387 - acc: 0.4839 - val_loss: 14824.3520 - val_acc: 0.6031
# Epoch 3/100
# 869/869 [==============================] - 29s 33ms/step - loss: 13003.9753 - acc: 0.6463 - val_loss: 9643.4600 - val_acc: 0.6605
# Epoch 4/100
# 869/869 [==============================] - 29s 33ms/step - loss: 8515.3207 - acc: 0.7142 - val_loss: 6288.4037 - val_acc: 0.7166
# Epoch 5/100
# 869/869 [==============================] - 29s 33ms/step - loss: 4971.1116 - acc: 0.7778 - val_loss: 3123.9740 - val_acc: 0.7805
# Epoch 6/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2505.0820 - acc: 0.8127 - val_loss: 1789.6340 - val_acc: 0.7633
# Epoch 7/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1496.6163 - acc: 0.8205 - val_loss: 1061.2740 - val_acc: 0.8659
# Epoch 8/100
# 869/869 [==============================] - 29s 33ms/step - loss: 904.7576 - acc: 0.8457 - val_loss: 650.1540 - val_acc: 0.8262
# Epoch 9/100
# 869/869 [==============================] - 29s 33ms/step - loss: 577.4216 - acc: 0.8499 - val_loss: 418.0170 - val_acc: 0.8881
# Epoch 10/100
# 869/869 [==============================] - 29s 33ms/step - loss: 378.4657 - acc: 0.8523 - val_loss: 279.2971 - val_acc: 0.8081
# Epoch 11/100
# 869/869 [==============================] - 29s 33ms/step - loss: 263.5145 - acc: 0.8524 - val_loss: 196.7551 - val_acc: 0.8791
# Epoch 12/100
# 869/869 [==============================] - 29s 33ms/step - loss: 192.4168 - acc: 0.8539 - val_loss: 145.4409 - val_acc: 0.9020
# Epoch 13/100
# 869/869 [==============================] - 29s 33ms/step - loss: 147.6500 - acc: 0.8606 - val_loss: 112.8689 - val_acc: 0.8533
# Epoch 14/100
# 869/869 [==============================] - 29s 33ms/step - loss: 117.9850 - acc: 0.8576 - val_loss: 89.7860 - val_acc: 0.8370
# Epoch 15/100
# 869/869 [==============================] - 29s 33ms/step - loss: 96.0909 - acc: 0.8625 - val_loss: 73.2779 - val_acc: 0.8103
# Epoch 16/100
# 869/869 [==============================] - 29s 33ms/step - loss: 80.4333 - acc: 0.8735 - val_loss: 61.6628 - val_acc: 0.7998
# Epoch 17/100
# 869/869 [==============================] - 29s 33ms/step - loss: 68.5476 - acc: 0.8564 - val_loss: 51.7249 - val_acc: 0.9162
# Epoch 18/100
# 869/869 [==============================] - 29s 33ms/step - loss: 58.6838 - acc: 0.8688 - val_loss: 44.1766 - val_acc: 0.8323
# Epoch 19/100
# 869/869 [==============================] - 29s 33ms/step - loss: 50.8684 - acc: 0.8686 - val_loss: 38.1146 - val_acc: 0.8289
# Epoch 20/100
# 869/869 [==============================] - 29s 34ms/step - loss: 44.6370 - acc: 0.8782 - val_loss: 33.2723 - val_acc: 0.8957
# Epoch 21/100
# 869/869 [==============================] - 29s 33ms/step - loss: 39.4634 - acc: 0.8723 - val_loss: 29.1758 - val_acc: 0.8057
# Epoch 22/100
# 869/869 [==============================] - 29s 33ms/step - loss: 35.3278 - acc: 0.8691 - val_loss: 25.8119 - val_acc: 0.8698
# Epoch 23/100
# 869/869 [==============================] - 29s 33ms/step - loss: 31.5514 - acc: 0.8723 - val_loss: 22.8928 - val_acc: 0.8528
# Epoch 24/100
# 869/869 [==============================] - 29s 33ms/step - loss: 28.3755 - acc: 0.8721 - val_loss: 20.4309 - val_acc: 0.8634
# Epoch 25/100
# 869/869 [==============================] - 29s 33ms/step - loss: 25.5937 - acc: 0.8723 - val_loss: 18.2663 - val_acc: 0.8410
# Epoch 26/100
# 869/869 [==============================] - 29s 33ms/step - loss: 23.1335 - acc: 0.8832 - val_loss: 16.4933 - val_acc: 0.8211
# Epoch 27/100
# 869/869 [==============================] - 29s 33ms/step - loss: 21.0965 - acc: 0.8782 - val_loss: 14.9289 - val_acc: 0.8543
# Epoch 28/100
# 869/869 [==============================] - 29s 33ms/step - loss: 19.2160 - acc: 0.8749 - val_loss: 13.5142 - val_acc: 0.8217
# Epoch 29/100
# 869/869 [==============================] - 29s 33ms/step - loss: 17.6417 - acc: 0.8794 - val_loss: 12.3251 - val_acc: 0.9201
# Epoch 30/100
# 869/869 [==============================] - 29s 33ms/step - loss: 16.2077 - acc: 0.8804 - val_loss: 11.2227 - val_acc: 0.8981
# Epoch 31/100
# 869/869 [==============================] - 29s 33ms/step - loss: 14.8991 - acc: 0.8802 - val_loss: 10.2723 - val_acc: 0.8373
# Epoch 32/100
# 869/869 [==============================] - 29s 33ms/step - loss: 13.7667 - acc: 0.8791 - val_loss: 9.4515 - val_acc: 0.9179
# Epoch 33/100
# 869/869 [==============================] - 29s 33ms/step - loss: 12.7528 - acc: 0.8821 - val_loss: 8.6748 - val_acc: 0.8351
# Epoch 34/100
# 869/869 [==============================] - 29s 33ms/step - loss: 11.7811 - acc: 0.8765 - val_loss: 8.0233 - val_acc: 0.8155
# Epoch 35/100
# 869/869 [==============================] - 29s 33ms/step - loss: 10.9986 - acc: 0.8766 - val_loss: 7.3924 - val_acc: 0.8655
# Epoch 36/100
# 869/869 [==============================] - 29s 33ms/step - loss: 10.1340 - acc: 0.8751 - val_loss: 6.8627 - val_acc: 0.9029
# Epoch 37/100
# 869/869 [==============================] - 29s 33ms/step - loss: 9.5009 - acc: 0.8883 - val_loss: 6.3575 - val_acc: 0.8249
# Epoch 38/100
# 869/869 [==============================] - 29s 33ms/step - loss: 8.9078 - acc: 0.8815 - val_loss: 5.9106 - val_acc: 0.8976
# Epoch 39/100
# 869/869 [==============================] - 29s 33ms/step - loss: 8.3364 - acc: 0.8651 - val_loss: 5.5077 - val_acc: 0.8927
# Epoch 40/100
# 869/869 [==============================] - 29s 33ms/step - loss: 7.8144 - acc: 0.8830 - val_loss: 5.1357 - val_acc: 0.8588
# Epoch 41/100
# 869/869 [==============================] - 29s 33ms/step - loss: 7.3017 - acc: 0.8925 - val_loss: 4.7919 - val_acc: 0.8601
# Epoch 42/100
# 869/869 [==============================] - 29s 33ms/step - loss: 6.8875 - acc: 0.8787 - val_loss: 4.4883 - val_acc: 0.8628
# Epoch 43/100
# 869/869 [==============================] - 29s 33ms/step - loss: 6.4655 - acc: 0.8856 - val_loss: 4.1968 - val_acc: 0.8687
# Epoch 44/100
# 869/869 [==============================] - 29s 33ms/step - loss: 6.0949 - acc: 0.8825 - val_loss: 3.9394 - val_acc: 0.8431
# Epoch 45/100
# 869/869 [==============================] - 29s 33ms/step - loss: 5.7291 - acc: 0.8697 - val_loss: 3.7025 - val_acc: 0.9282
# Epoch 46/100
# 869/869 [==============================] - 29s 33ms/step - loss: 5.4247 - acc: 0.8841 - val_loss: 3.4849 - val_acc: 0.8848
# Epoch 47/100
# 869/869 [==============================] - 29s 33ms/step - loss: 5.1192 - acc: 0.8981 - val_loss: 3.2750 - val_acc: 0.8684
# Epoch 48/100
# 869/869 [==============================] - 29s 33ms/step - loss: 4.8643 - acc: 0.8720 - val_loss: 3.0853 - val_acc: 0.8930
# Epoch 49/100
# 869/869 [==============================] - 29s 33ms/step - loss: 4.5464 - acc: 0.8855 - val_loss: 2.9136 - val_acc: 0.8991
# Epoch 50/100
# 869/869 [==============================] - 29s 33ms/step - loss: 4.3730 - acc: 0.8867 - val_loss: 2.7553 - val_acc: 0.8565
# Epoch 51/100
# 869/869 [==============================] - 29s 33ms/step - loss: 4.1505 - acc: 0.8855 - val_loss: 2.5998 - val_acc: 0.8113
# Epoch 52/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.9377 - acc: 0.8708 - val_loss: 2.4586 - val_acc: 0.8253
# Epoch 53/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.7392 - acc: 0.8760 - val_loss: 2.3382 - val_acc: 0.8743
# Epoch 54/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.5427 - acc: 0.8802 - val_loss: 2.2061 - val_acc: 0.8692
# Epoch 55/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.3908 - acc: 0.8804 - val_loss: 2.0945 - val_acc: 0.9056
# Epoch 56/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.2128 - acc: 0.8821 - val_loss: 1.9899 - val_acc: 0.9139
# Epoch 57/100
# 869/869 [==============================] - 29s 33ms/step - loss: 3.0812 - acc: 0.8889 - val_loss: 1.8860 - val_acc: 0.8966
# Epoch 58/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.9353 - acc: 0.8885 - val_loss: 1.7887 - val_acc: 0.8845
# Epoch 59/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.7984 - acc: 0.8843 - val_loss: 1.7060 - val_acc: 0.8373
# Epoch 60/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.6561 - acc: 0.8665 - val_loss: 1.6233 - val_acc: 0.8754
# Epoch 61/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.5532 - acc: 0.8930 - val_loss: 1.5443 - val_acc: 0.9051
# Epoch 62/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.4405 - acc: 0.8819 - val_loss: 1.4728 - val_acc: 0.8914
# Epoch 63/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.3338 - acc: 0.8839 - val_loss: 1.4022 - val_acc: 0.8757
# Epoch 64/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.2313 - acc: 0.8937 - val_loss: 1.3367 - val_acc: 0.8851
# Epoch 65/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.1326 - acc: 0.8944 - val_loss: 1.2790 - val_acc: 0.8282
# Epoch 66/100
# 869/869 [==============================] - 29s 33ms/step - loss: 2.0339 - acc: 0.8838 - val_loss: 1.2191 - val_acc: 0.8607
# Epoch 67/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.9446 - acc: 0.8944 - val_loss: 1.1631 - val_acc: 0.8717
# Epoch 68/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.8721 - acc: 0.8887 - val_loss: 1.1102 - val_acc: 0.8565
# Epoch 69/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.7972 - acc: 0.8822 - val_loss: 1.0622 - val_acc: 0.8934
# Epoch 70/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.7194 - acc: 0.8949 - val_loss: 1.0168 - val_acc: 0.8554
# Epoch 71/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.6435 - acc: 0.8852 - val_loss: 0.9701 - val_acc: 0.8266
# Epoch 72/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.5857 - acc: 0.8941 - val_loss: 0.9302 - val_acc: 0.8430
# Epoch 73/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.5065 - acc: 0.8870 - val_loss: 0.8893 - val_acc: 0.8437
# Epoch 74/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.4610 - acc: 0.8820 - val_loss: 0.8513 - val_acc: 0.8640
# Epoch 75/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.3996 - acc: 0.8929 - val_loss: 0.8175 - val_acc: 0.8976
# Epoch 76/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.3417 - acc: 0.8826 - val_loss: 0.7816 - val_acc: 0.8721
# Epoch 77/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.2747 - acc: 0.8952 - val_loss: 0.7541 - val_acc: 0.8418
# Epoch 78/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.2339 - acc: 0.8989 - val_loss: 0.7207 - val_acc: 0.8196
# Epoch 79/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.1933 - acc: 0.8936 - val_loss: 0.6922 - val_acc: 0.8229
# Epoch 80/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.1428 - acc: 0.8934 - val_loss: 0.6623 - val_acc: 0.8438
# Epoch 81/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.1020 - acc: 0.8838 - val_loss: 0.6384 - val_acc: 0.9301
# Epoch 82/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.0568 - acc: 0.8932 - val_loss: 0.6095 - val_acc: 0.8837
# Epoch 83/100
# 869/869 [==============================] - 29s 33ms/step - loss: 1.0193 - acc: 0.8958 - val_loss: 0.5886 - val_acc: 0.8772
# Epoch 84/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.9817 - acc: 0.8913 - val_loss: 0.5623 - val_acc: 0.8807
# Epoch 85/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.9418 - acc: 0.8925 - val_loss: 0.5435 - val_acc: 0.9168
# Epoch 86/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.9076 - acc: 0.8967 - val_loss: 0.5205 - val_acc: 0.9301
# Epoch 87/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.8739 - acc: 0.8922 - val_loss: 0.5019 - val_acc: 0.8614
# Epoch 88/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.8427 - acc: 0.8829 - val_loss: 0.4821 - val_acc: 0.8369
# Epoch 89/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.8109 - acc: 0.8860 - val_loss: 0.4648 - val_acc: 0.8934
# Epoch 90/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.7809 - acc: 0.8904 - val_loss: 0.4455 - val_acc: 0.8989
# Epoch 91/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.7512 - acc: 0.8997 - val_loss: 0.4302 - val_acc: 0.8367
# Epoch 92/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.7257 - acc: 0.8784 - val_loss: 0.4142 - val_acc: 0.9266
# Epoch 93/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.6950 - acc: 0.8896 - val_loss: 0.3984 - val_acc: 0.8906
# Epoch 94/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.6705 - acc: 0.8958 - val_loss: 0.3835 - val_acc: 0.8492
# Epoch 95/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.6432 - acc: 0.8921 - val_loss: 0.3707 - val_acc: 0.8859
# Epoch 96/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.6249 - acc: 0.8934 - val_loss: 0.3571 - val_acc: 0.8868
# Epoch 97/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.5953 - acc: 0.8844 - val_loss: 0.3438 - val_acc: 0.8701
# Epoch 98/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.5803 - acc: 0.8877 - val_loss: 0.3302 - val_acc: 0.8606
# Epoch 99/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.5581 - acc: 0.8959 - val_loss: 0.3199 - val_acc: 0.8574
# Epoch 100/100
# 869/869 [==============================] - 29s 33ms/step - loss: 0.5402 - acc: 0.8975 - val_loss: 0.3081 - val_acc: 0.8562
# 218/218 [==============================] - 2s 10ms/step
#
# Saving files...
# Saving plots...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving model architecture...
# Zipping files...
#   adding: model_summary.txt (deflated 94%)
#   adding: results.png (deflated 2%)
#   adding: plots.png (deflated 7%)
#   adding: model.json (deflated 97%)
# Storing files in designated folder...
